# %%
import pandas as pd

# %%
data = pd.read_csv('D:/python practise/python_prc/python_prc/python_prc/customer (1).csv', header = 0 , index_col= 0)

# %%
print(data)
# Out:
#               customer_name      segment  age        country  \
# cust_id
# CG-12520        Claire Gute     Consumer   67  United States
# DV-13045    Darrin Van Huff    Corporate   31  United States
# SO-20335     Sean O'Donnell     Consumer   65  United States
# BH-11710    Brosina Hoffman     Consumer   20  United States
# AA-10480       Andrew Allen     Consumer   50  United States
# ...                     ...          ...  ...            ...
# CJ-11875       Carl Jackson    Corporate   64  United States
# RS-19870         Roy Skaria  Home Office   39  United States
# SC-20845         Sung Chung     Consumer   69  United States
# RE-19405    Ricardo Emerson     Consumer   35  United States
# SM-20905  Susan MacKendrick     Consumer   46  United States
#
#                        city           state  postal_code   region
# cust_id
# CG-12520          Henderson        Kentucky        42420    South
# DV-13045        Los Angeles      California        90036     West
# ...

# %%
data1 = data.head(50)

# %%
print(data)
# Out:
#               customer_name      segment  age        country  \
# cust_id
# CG-12520        Claire Gute     Consumer   67  United States
# DV-13045    Darrin Van Huff    Corporate   31  United States
# SO-20335     Sean O'Donnell     Consumer   65  United States
# BH-11710    Brosina Hoffman     Consumer   20  United States
# AA-10480       Andrew Allen     Consumer   50  United States
# ...                     ...          ...  ...            ...
# CJ-11875       Carl Jackson    Corporate   64  United States
# RS-19870         Roy Skaria  Home Office   39  United States
# SC-20845         Sung Chung     Consumer   69  United States
# RE-19405    Ricardo Emerson     Consumer   35  United States
# SM-20905  Susan MacKendrick     Consumer   46  United States
#
#                        city           state  postal_code   region
# cust_id
# CG-12520          Henderson        Kentucky        42420    South
# DV-13045        Los Angeles      California        90036     West
# ...

# %%
data3  = data1.to_dict(orient='records')

# %%
data3
# Out:
# [{'customer_name': 'Claire Gute',
#   'segment': 'Consumer',
#   'age': 67,
#   'country': 'United States',
#   'city': 'Henderson',
#   'state': 'Kentucky',
#   'postal_code': 42420,
#   'region': 'South'},
#  {'customer_name': 'Darrin Van Huff',
#   'segment': 'Corporate',
#   'age': 31,
#   'country': 'United States',
#   'city': 'Los Angeles',
#   'state': 'California',
#   'postal_code': 90036,
#   'region': 'West'},
#  {'customer_name': "Sean O'Donnell",
#   'segment': 'Consumer',
#   'age': 65,
#   'country': 'United States',
#   'city': 'Fort Lauderdale',
#   'state': 'Florida',
#   'postal_code': 33311,
#   'region': 'South'},
#  {'customer_name': 'Brosina Hoffman',
#   'segment': 'Consumer',
#   'age': 20,
#   'country': 'United States',
#   'city': 'Los Angeles',
#   'state': 'California',
#   'postal_code': 90032,
#   'region': 'West'},
#  {'customer_name': 'Andrew Allen',
#   'segment': 'Consumer',
#   'age': 50,
#   'country': 'United States',
#   'city': 'Concord',
# ...

# %%
Final = pd.DataFrame(data3)

# %%
Final
# Out:
#          customer_name      segment  age        country             city  \
# 0          Claire Gute     Consumer   67  United States        Henderson
# 1      Darrin Van Huff    Corporate   31  United States      Los Angeles
# 2       Sean O'Donnell     Consumer   65  United States  Fort Lauderdale
# 3      Brosina Hoffman     Consumer   20  United States      Los Angeles
# 4         Andrew Allen     Consumer   50  United States          Concord
# 5         Irene Maddox     Consumer   66  United States          Seattle
# 6        Harold Pawlan  Home Office   20  United States       Fort Worth
# 7            Pete Kriz     Consumer   46  United States          Madison
# 8      Alejandro Grove     Consumer   18  United States      West Jordan
# 9   Zuschuss Donatelli     Consumer   66  United States    San Francisco
# 10           Ken Black    Corporate   67  United States          Fremont
# 11     Sandra Flanagan     Consumer   41  United States     Philadelphia
# ...

# %%
Final.to_csv('cust.csv', index=False)

# %%
Final.describe()
# Out:
#             age   postal_code
# count  50.00000     50.000000
# mean   43.52000  58729.520000
# std    17.64299  27879.805501
# min    18.00000  10009.000000
# 25%    29.50000  33883.500000
# 50%    41.50000  60575.000000
# 75%    63.00000  84077.250000
# max    70.00000  98103.000000
