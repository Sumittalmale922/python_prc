# %%
import pandas as pd

# %%
data = pd.read_csv ('D:/python practise/python_prc/python_prc/python_prc/product.csv')

# %%
print(data)
# Out:
#            product_id         category sub_category  \
# 0     FUR-BO-10001798        Furniture    Bookcases
# 1     FUR-CH-10000454        Furniture       Chairs
# 2     OFF-LA-10000240  Office Supplies       Labels
# 3     FUR-TA-10000577        Furniture       Tables
# 4     OFF-ST-10000760  Office Supplies      Storage
# ...               ...              ...          ...
# 1857  TEC-PH-10002817       Technology       Phones
# 1858  TEC-MA-10003589       Technology     Machines
# 1859  OFF-AP-10003099  Office Supplies   Appliances
# 1860  TEC-PH-10002645       Technology       Phones
# 1861  OFF-ST-10001627  Office Supplies      Storage
#
#                                            product_name
# 0                     Bush Somerset Collection Bookcase
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs ...
# 2     Self-Adhesive Address Labels for Typewriters b...
# 3         Bretford CR4500 Series Slim Rectangular Table
# ...

# %%
data1 = data.head(50)

# %%
print(data)
# Out:
#            product_id         category sub_category  \
# 0     FUR-BO-10001798        Furniture    Bookcases
# 1     FUR-CH-10000454        Furniture       Chairs
# 2     OFF-LA-10000240  Office Supplies       Labels
# 3     FUR-TA-10000577        Furniture       Tables
# 4     OFF-ST-10000760  Office Supplies      Storage
# ...               ...              ...          ...
# 1857  TEC-PH-10002817       Technology       Phones
# 1858  TEC-MA-10003589       Technology     Machines
# 1859  OFF-AP-10003099  Office Supplies   Appliances
# 1860  TEC-PH-10002645       Technology       Phones
# 1861  OFF-ST-10001627  Office Supplies      Storage
#
#                                            product_name
# 0                     Bush Somerset Collection Bookcase
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs ...
# 2     Self-Adhesive Address Labels for Typewriters b...
# 3         Bretford CR4500 Series Slim Rectangular Table
# ...

# %%
data = data1.to_dict(orient='records')

# %%
data1
# Out:
#          product_id         category sub_category  \
# 0   FUR-BO-10001798        Furniture    Bookcases
# 1   FUR-CH-10000454        Furniture       Chairs
# 2   OFF-LA-10000240  Office Supplies       Labels
# 3   FUR-TA-10000577        Furniture       Tables
# 4   OFF-ST-10000760  Office Supplies      Storage
# 5   FUR-FU-10001487        Furniture  Furnishings
# 6   OFF-AR-10002833  Office Supplies          Art
# 7   TEC-PH-10002275       Technology       Phones
# 8   OFF-BI-10003910  Office Supplies      Binders
# 9   OFF-AP-10002892  Office Supplies   Appliances
# 10  FUR-TA-10001539        Furniture       Tables
# 11  TEC-PH-10002033       Technology       Phones
# 12  OFF-PA-10002365  Office Supplies        Paper
# 13  OFF-BI-10003656  Office Supplies      Binders
# 14  OFF-AP-10002311  Office Supplies   Appliances
# 15  OFF-BI-10000756  Office Supplies      Binders
# 16  OFF-ST-10004186  Office Supplies      Storage
# 17  OFF-ST-10000107  Office Supplies      Storage
# ...

# %%
final = pd.DataFrame(data1)

# %%
final
# Out:
#          product_id         category sub_category  \
# 0   FUR-BO-10001798        Furniture    Bookcases
# 1   FUR-CH-10000454        Furniture       Chairs
# 2   OFF-LA-10000240  Office Supplies       Labels
# 3   FUR-TA-10000577        Furniture       Tables
# 4   OFF-ST-10000760  Office Supplies      Storage
# 5   FUR-FU-10001487        Furniture  Furnishings
# 6   OFF-AR-10002833  Office Supplies          Art
# 7   TEC-PH-10002275       Technology       Phones
# 8   OFF-BI-10003910  Office Supplies      Binders
# 9   OFF-AP-10002892  Office Supplies   Appliances
# 10  FUR-TA-10001539        Furniture       Tables
# 11  TEC-PH-10002033       Technology       Phones
# 12  OFF-PA-10002365  Office Supplies        Paper
# 13  OFF-BI-10003656  Office Supplies      Binders
# 14  OFF-AP-10002311  Office Supplies   Appliances
# 15  OFF-BI-10000756  Office Supplies      Binders
# 16  OFF-ST-10004186  Office Supplies      Storage
# 17  OFF-ST-10000107  Office Supplies      Storage
# ...

# %%
final. to_csv('cust.csv',index=False)

# %%
final.describe
# Out:
# <bound method NDFrame.describe of          product_id         category sub_category  \
# 0   FUR-BO-10001798        Furniture    Bookcases
# 1   FUR-CH-10000454        Furniture       Chairs
# 2   OFF-LA-10000240  Office Supplies       Labels
# 3   FUR-TA-10000577        Furniture       Tables
# 4   OFF-ST-10000760  Office Supplies      Storage
# 5   FUR-FU-10001487        Furniture  Furnishings
# 6   OFF-AR-10002833  Office Supplies          Art
# 7   TEC-PH-10002275       Technology       Phones
# 8   OFF-BI-10003910  Office Supplies      Binders
# 9   OFF-AP-10002892  Office Supplies   Appliances
# 10  FUR-TA-10001539        Furniture       Tables
# 11  TEC-PH-10002033       Technology       Phones
# 12  OFF-PA-10002365  Office Supplies        Paper
# 13  OFF-BI-10003656  Office Supplies      Binders
# 14  OFF-AP-10002311  Office Supplies   Appliances
# 15  OFF-BI-10000756  Office Supplies      Binders
# 16  OFF-ST-10004186  Office Supplies      Storage
# ...
