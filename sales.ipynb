# %%
import pandas as pd

# %%
data = pd.read_csv('D:/python practise/python_prc/python_prc/python_prc/sales.csv')

# %%
print(data)
# Out:
#       order_line        order_id  order_date   ship_date       ship_mode  \
# 0              1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1              2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2              3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3              4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4              5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...          ...             ...         ...         ...             ...
# 9990        9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9991        9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992        9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993        9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9994        9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      customer_id       product_id     sales  quantity  discount    profit
# ...

# %%
data1 = data.head(50)

# %%
print(data)
# Out:
#       order_line        order_id  order_date   ship_date       ship_mode  \
# 0              1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1              2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2              3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3              4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4              5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...          ...             ...         ...         ...             ...
# 9990        9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9991        9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992        9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993        9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9994        9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      customer_id       product_id     sales  quantity  discount    profit
# ...

# %%
data = data1.to_dict(orient='records')

# %%
data1
# Out:
#     order_line        order_id  order_date   ship_date       ship_mode  \
# 0            1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1            2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2            3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3            4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4            5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 5            6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 6            7  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 7            8  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 8            9  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 9           10  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 10          11  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 11          12  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# ...

# %%
final = pd.DataFrame(data1)

# %%
final
# Out:
#     order_line        order_id  order_date   ship_date       ship_mode  \
# 0            1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1            2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2            3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3            4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4            5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 5            6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 6            7  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 7            8  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 8            9  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 9           10  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 10          11  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 11          12  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# ...

# %%
final. to_csv('cust.csv',index=False)

# %%
final.describe
# Out:
# <bound method NDFrame.describe of     order_line        order_id  order_date   ship_date       ship_mode  \
# 0            1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1            2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2            3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3            4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4            5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 5            6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 6            7  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 7            8  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 8            9  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 9           10  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 10          11  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 11          12  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# ...
